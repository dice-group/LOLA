# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from huggingface_hub import HfApi
api = HfApi()

# %%
# To create repo if does not exists
api.create_repo(
    repo_id="dice-research/lola_instructions_lora",
    repo_type="model",
)

# %%
# To upload to existing repo
api.upload_folder(
    folder_path="./lola_aya_alpaca_multilingual_peft__attn_rank32",
    repo_id="dice-research/lola_instructions_lora",
    repo_type="model",
)
